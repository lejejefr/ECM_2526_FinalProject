# %% [markdown]
# <a href="https://colab.research.google.com/github/lejejefr/ECM_2526_FinalProject/blob/main/Sripts/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install PyGithub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 11.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 49.7 MB/s eta 0:00:00
# ...

# %%
#ce script sert à nettoyer les données pour notre training set
from github import Github
import pandas as pd
url = 'https://raw.githubusercontent.com/lejejefr/ECM_2526_FinalProject/refs/heads/main/Data/RawData.csv'
df = pd.read_csv(url)
df.head()


nb_nulles = df.isnull().sum() # Montrer le nb de valeurs nulles ds chq colonne print("valeurs nulles par colonne:")
print(nb_nulles)
# Out:
# ID                        0
# Case Number               0
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description      0
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  0
# Ward                    380
# Community Area          380
# FBI Code                  0
# X Coordinate              3
# Y Coordinate              3
# Year                      0
# Updated On                0
# Latitude                  3
# Longitude                 3
# Location                  3
# dtype: int64

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df.head()
# Out:
#       ID Case Number                    Date                    Block  IUCR  \
# 0  28910    JJ442189  10/06/2025 05:19:00 PM          016XX W 79TH ST   110
# 1  28909    JJ442109  10/06/2025 05:15:00 PM     000XX N KILBOURN AVE   110
# 2  28908    JJ441599  10/06/2025 09:17:00 AM  056XX W WASHINGTON BLVD   110
# 3  28907    JJ441303  10/06/2025 03:36:00 AM          026XX W 39TH PL   110
# 4  28906    JJ439875  10/04/2025 08:35:00 PM     038XX W ROOSEVELT RD   110
#
#   Primary Type          Description Location Description  Arrest  Domestic  \
# 0     HOMICIDE  FIRST DEGREE MURDER          PARKING LOT   False     False
# 1     HOMICIDE  FIRST DEGREE MURDER          GAS STATION   False     False
# 2     HOMICIDE  FIRST DEGREE MURDER            APARTMENT   False      True
# 3     HOMICIDE  FIRST DEGREE MURDER               STREET   False     False
# 4     HOMICIDE  FIRST DEGREE MURDER          PARKING LOT   False     False
#
# ...

# %%
df.drop('Arrest', axis=1)
# Out:
#           ID Case Number                    Date                    Block  \
# 0      28910    JJ442189  10/06/2025 05:19:00 PM          016XX W 79TH ST
# 1      28909    JJ442109  10/06/2025 05:15:00 PM     000XX N KILBOURN AVE
# 2      28908    JJ441599  10/06/2025 09:17:00 AM  056XX W WASHINGTON BLVD
# 3      28907    JJ441303  10/06/2025 03:36:00 AM          026XX W 39TH PL
# 4      28906    JJ439875  10/04/2025 08:35:00 PM     038XX W ROOSEVELT RD
# ...      ...         ...                     ...                      ...
# 13972    638     G008793  01/05/2001 04:22:00 PM            016XX W 80 ST
# 13973    636     G008548  01/04/2001 10:30:00 PM            035XX W 12 PL
# 13974    643     D362053  01/04/2001 10:05:00 PM            002XX E 46 ST
# 13975    635     F803142  01/01/2001 03:10:00 PM    023XX N MILWAUKEE AVE
# 13976    634     G000705  01/01/2001 10:40:00 AM        024XX W MONROE ST
#
#        IUCR Primary Type          Description Location Description  Domestic  \
# ...

# %%
#je suis en train de taffer sur le projet homicide (je veux qu'on l'appelle comme ça à partir de maintenant.),
#je suis en train de poursuivre le nettoyage des données. pour l'instant j'ai créé un nouveau data frame qu'on
#utilisera pour entrainer le modèle avec ID, heure, jour de la semaine, jour de l'année, latitude et longitude.
#j'ai mis heure jour semaine et jour mois pour voir si y a de la saisonnalité (genre plus de crime la nuit, le
#week end, l'hiver). On a pas besoin de la colonne primary type parce qu'on a gardé que les homicides, et les
#autres colonnes je vois pas à quoi elles servent. si ça vous semble correct ba let's go

select = pd.DataFrame()
select['ID'] = df['ID']

dates = pd.to_datetime(df['Date'])

select['time'] = dates.dt.hour * 3600 + dates.dt.minute * 60 + dates.dt.second
select['day of week'] = dates.dt.day_of_week
select['day of year'] = dates.dt.day_of_year

select['latitude'] = df['Latitude']
select['longitude'] = df['Longitude']

select.head()
# Out:
# /tmp/ipython-input-2880967489.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dates = pd.to_datetime(df['Date'])
#       ID   time  day of week  day of year   latitude  longitude
# 0  28910  62340            0          279  41.750334 -87.665045
# 1  28909  62100            0          279  41.880968 -87.737940
# 2  28908  33420            0          279  41.882208 -87.767204
# 3  28907  12960            0          279  41.821964 -87.690298
# 4  28906  74100            5          277  41.866235 -87.720517

# %%
select.describe()
# Out:
#                  ID          time   day of week   day of year      latitude  \
# count  1.397700e+04  13977.000000  13977.000000  13977.000000  13974.000000
# mean   8.266806e+04  44369.509838      3.230808    190.478429     41.803527
# std    8.591178e+05  27954.303147      2.061751     97.001747      0.278424
# min    6.340000e+02      0.000000      0.000000      1.000000     36.619446
# 25%    4.130000e+03  15720.000000      1.000000    116.000000     41.756634
# 50%    2.175900e+04  48600.000000      3.000000    192.000000     41.803265
# 75%    2.540400e+04  69960.000000      5.000000    268.000000     41.880751
# max    1.373461e+07  86340.000000      6.000000    366.000000     42.022548
#
#           longitude
# count  13974.000000
# mean     -87.678826
# std        0.214317
# min      -91.686566
# 25%      -87.715184
# 50%      -87.665442
# 75%      -87.624720
# max      -87.525759

# %%
clean_df = select.drop(select[(select["latitude"] < 36.7) & (select["longitude"] < -91.6)].index)
clean_df.describe()
#--> on voit que les données ne comportent qu'un seul vrai outlier (probablement une erreur)
# Out:
#                  ID          time   day of week  day of year      latitude  \
# count  1.394000e+04  13940.000000  13940.000000  13940.00000  13937.000000
# mean   8.288289e+04  44380.933931      3.230273    190.47231     41.817290
# std    8.602471e+05  27943.989010      2.061345     97.01024      0.078640
# min    6.340000e+02      0.000000      0.000000      1.00000     41.644818
# 25%    4.157750e+03  15780.000000      1.000000    115.75000     41.757257
# 50%    2.178050e+04  48600.000000      3.000000    192.00000     41.803585
# 75%    2.541325e+04  69960.000000      5.000000    268.00000     41.880778
# max    1.373461e+07  86340.000000      6.000000    366.00000     42.022548
#
#           longitude
# count  13937.000000
# mean     -87.668187
# std        0.057413
# min      -87.904123
# 25%      -87.714760
# 50%      -87.665192
# 75%      -87.624568
# max      -87.525759

# %%
g = Github()
repo = g.get_user().get_repo("ECM_2526_FinalProject")


csv_content = clean_df.to_csv(index=False)


repo.create_file(
    path="Data/CleanData.csv",
    message="Add cleaned data",
    content=csv_content,
    branch="main"
)
# Out:
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# /tmp/ipython-input-3479995168.py in <cell line: 0>()
#       1 g = Github()
# ----> 2 repo = g.get_user().get_repo("ECM_2526_FinalProject")
#       3
#       4
#       5 csv_content = clean_df.to_csv(index=False)
#
# /usr/local/lib/python3.12/dist-packages/github/AuthenticatedUser.py in get_repo(self, name)
#     864         assert isinstance(name, str), name
#     865         name = urllib.parse.quote(name)
# --> 866         headers, data = self._requester.requestJsonAndCheck("GET", f"/repos/{self.login}/{name}")
#     867         return github.Repository.Repository(self._requester, headers, data, completed=True)
#     868
#
# /usr/local/lib/python3.12/dist-packages/github/AuthenticatedUser.py in login(self)
#     292     @property
#     293     def login(self) -> str:
# --> 294         self._completeIfNotSet(self._login)
# ...
