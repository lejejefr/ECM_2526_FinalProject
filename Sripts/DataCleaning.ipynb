# %% [markdown]
# <a href="https://colab.research.google.com/github/lejejefr/ECM_2526_FinalProject/blob/main/Sripts/DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ce script sert à nettoyer les données pour notre training set
import pandas as pd
url = 'https://raw.githubusercontent.com/lejejefr/ECM_2526_FinalProject/refs/heads/main/Data/RawData.csv'
df = pd.read_csv(url)
df.head()


nb_nulles = df.isnull().sum() # Montrer le nb de valeurs nulles ds chq colonne print("valeurs nulles par colonne:")
print(nb_nulles)
# Out:
# ID                        0
# Case Number               0
# Date                      0
# Block                     0
# IUCR                      0
# Primary Type              0
# Description               0
# Location Description      0
# Arrest                    0
# Domestic                  0
# Beat                      0
# District                  0
# Ward                    380
# Community Area          380
# FBI Code                  0
# X Coordinate              3
# Y Coordinate              3
# Year                      0
# Updated On                0
# Latitude                  3
# Longitude                 3
# Location                  3
# dtype: int64

# %%
duplicate_rows = df[df.duplicated()]
duplicate_rows
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, X Coordinate, Y Coordinate, Year, Latitude, Longitude, Location]
# Index: []

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'Primary Type', 'Description',
#        'Location Description', 'Arrest', 'Domestic', 'Beat', 'District',
#        'Ward', 'Community Area', 'X Coordinate', 'Y Coordinate', 'Year',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df.head()
# Out:
#       ID Case Number                    Date                    Block  \
# 0  28910    JJ442189  10/06/2025 05:19:00 PM          016XX W 79TH ST
# 1  28909    JJ442109  10/06/2025 05:15:00 PM     000XX N KILBOURN AVE
# 2  28908    JJ441599  10/06/2025 09:17:00 AM  056XX W WASHINGTON BLVD
# 3  28907    JJ441303  10/06/2025 03:36:00 AM          026XX W 39TH PL
# 4  28906    JJ439875  10/04/2025 08:35:00 PM     038XX W ROOSEVELT RD
#
#   Primary Type          Description Location Description  Arrest  Domestic  \
# 0     HOMICIDE  FIRST DEGREE MURDER          PARKING LOT   False     False
# 1     HOMICIDE  FIRST DEGREE MURDER          GAS STATION   False     False
# 2     HOMICIDE  FIRST DEGREE MURDER            APARTMENT   False      True
# 3     HOMICIDE  FIRST DEGREE MURDER               STREET   False     False
# 4     HOMICIDE  FIRST DEGREE MURDER          PARKING LOT   False     False
#
#    Beat  District  Ward  Community Area  X Coordinate  Y Coordinate  Year  \
# 0   611         6  17.0            71.0     1166608.0     1852321.0  2025
# 1  1113        11  28.0            26.0     1146387.0     1899777.0  2025
# 2  1513        15  29.0            25.0     1138415.0     1900175.0  2025
# 3   921         9  12.0            58.0     1159522.0     1878370.0  2025
# 4  1011        10  24.0            29.0     1151170.0     1894442.0  2025
#
#     Latitude  Longitude                       Location
# 0  41.750334 -87.665045   (41.75033427, -87.665045312)
# 1  41.880968 -87.737940   (41.88096768, -87.737940272)
# 2  41.882208 -87.767204   (41.88220788, -87.767203679)
# 3  41.821964 -87.690298  (41.821964415, -87.690297894)
# 4  41.866235 -87.720517  (41.866235446, -87.720517147)

# %%
df.drop('Arrest', axis=1)
# Out:
#           ID Case Number                    Date                    Block  \
# 0      28910    JJ442189  10/06/2025 05:19:00 PM          016XX W 79TH ST
# 1      28909    JJ442109  10/06/2025 05:15:00 PM     000XX N KILBOURN AVE
# 2      28908    JJ441599  10/06/2025 09:17:00 AM  056XX W WASHINGTON BLVD
# 3      28907    JJ441303  10/06/2025 03:36:00 AM          026XX W 39TH PL
# 4      28906    JJ439875  10/04/2025 08:35:00 PM     038XX W ROOSEVELT RD
# ...      ...         ...                     ...                      ...
# 13972    638     G008793  01/05/2001 04:22:00 PM            016XX W 80 ST
# 13973    636     G008548  01/04/2001 10:30:00 PM            035XX W 12 PL
# 13974    643     D362053  01/04/2001 10:05:00 PM            002XX E 46 ST
# 13975    635     F803142  01/01/2001 03:10:00 PM    023XX N MILWAUKEE AVE
# 13976    634     G000705  01/01/2001 10:40:00 AM        024XX W MONROE ST
#
#       Primary Type          Description Location Description  Domestic  Beat  \
# 0         HOMICIDE  FIRST DEGREE MURDER          PARKING LOT     False   611
# 1         HOMICIDE  FIRST DEGREE MURDER          GAS STATION     False  1113
# 2         HOMICIDE  FIRST DEGREE MURDER            APARTMENT      True  1513
# 3         HOMICIDE  FIRST DEGREE MURDER               STREET     False   921
# 4         HOMICIDE  FIRST DEGREE MURDER          PARKING LOT     False  1011
# ...            ...                  ...                  ...       ...   ...
# 13972     HOMICIDE  FIRST DEGREE MURDER               STREET     False   611
# 13973     HOMICIDE  FIRST DEGREE MURDER             BASEMENT     False  1021
# 13974     HOMICIDE  FIRST DEGREE MURDER   ABANDONED BUILDING     False   221
# 13975     HOMICIDE  FIRST DEGREE MURDER                 AUTO     False  1414
# 13976     HOMICIDE  FIRST DEGREE MURDER        CHA STAIRWELL     False  1125
#
#        District  Ward  Community Area  X Coordinate  Y Coordinate  Year  \
# 0             6  17.0            71.0     1166608.0     1852321.0  2025
# 1            11  28.0            26.0     1146387.0     1899777.0  2025
# 2            15  29.0            25.0     1138415.0     1900175.0  2025
# 3             9  12.0            58.0     1159522.0     1878370.0  2025
# 4            10  24.0            29.0     1151170.0     1894442.0  2025
# ...         ...   ...             ...           ...           ...   ...
# 13972         6   NaN             NaN     1166640.0     1851658.0  2001
# 13973        10   NaN             NaN     1153021.0     1894062.0  2001
# 13974         2   NaN             NaN     1178501.0     1874572.0  2001
# 13975        14  35.0            22.0     1156620.0     1915710.0  2001
# 13976        11   2.0            28.0     1159921.0     1899604.0  2001
#
#         Latitude  Longitude                       Location
# 0      41.750334 -87.665045   (41.75033427, -87.665045312)
# 1      41.880968 -87.737940   (41.88096768, -87.737940272)
# 2      41.882208 -87.767204   (41.88220788, -87.767203679)
# 3      41.821964 -87.690298  (41.821964415, -87.690297894)
# 4      41.866235 -87.720517  (41.866235446, -87.720517147)
# ...          ...        ...                            ...
# 13972  41.748514 -87.664947  (41.748514222, -87.664946923)
# 13973  41.865156 -87.713732   (41.865156224, -87.71373199)
# 13974  41.811132 -87.620788   (41.81113151, -87.620788483)
# 13975  41.924488 -87.699933  (41.924488265, -87.699933231)
# 13976  41.880225 -87.688249  (41.880224549, -87.688248952)
#
# [13977 rows x 18 columns]

# %%
#je suis en train de taffer sur le projet homicide (je veux qu'on l'appelle comme ça à partir de maintenant.),
#je suis en train de poursuivre le nettoyage des données. pour l'instant j'ai créé un nouveau data frame qu'on
#utilisera pour entrainer le modèle avec ID, heure, jour de la semaine, jour de l'année, latitude et longitude.
#j'ai mis heure jour semaine et jour mois pour voir si y a de la saisonnalité (genre plus de crime la nuit, le
#week end, l'hiver). On a pas besoin de la colonne primary type parce qu'on a gardé que les homicides, et les
#autres colonnes je vois pas à quoi elles servent. si ça vous semble correct ba let's go

clean_df = pd.DataFrame()
clean_df['ID'] = df['ID']

dates = pd.to_datetime(df['Date'])

clean_df['time'] = dates.dt.hour * 3600 + dates.dt.minute * 60 + dates.dt.second
clean_df['day of week'] = dates.dt.day_of_week
clean_df['day of year'] = dates.dt.day_of_year

clean_df['latitude'] = df['Latitude']
clean_df['longitude'] = df['Longitude']

clean_df.head()
# Out:
# /tmp/ipython-input-3209288286.py:11: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dates = pd.to_datetime(df['Date'])
#       ID   time  day of week  day of year   latitude  longitude
# 0  28910  62340            0          279  41.750334 -87.665045
# 1  28909  62100            0          279  41.880968 -87.737940
# 2  28908  33420            0          279  41.882208 -87.767204
# 3  28907  12960            0          279  41.821964 -87.690298
# 4  28906  74100            5          277  41.866235 -87.720517

# %%
g = Github()
repo = g.get_user().get_repo("ECM_2526_FinalProject")


csv_content = clean_df.to_csv(index=False)


repo.create_file(
    path="Data/CleanData.csv",
    message="Add cleaned data",
    content=csv_content,
    branch="main"
)
