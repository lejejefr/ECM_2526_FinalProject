# %% [markdown]
# <a href="https://colab.research.google.com/github/lejejefr/ECM_2526_FinalProject/blob/main/Crimes_Algorithme_KDE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
